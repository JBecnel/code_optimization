# %%
import numpy as np

y_values = np.arange(-5, 5.01, 0.01)
x_values = np.arange(0.0, 10.01, 0.01)

array = np.round(np.divide(y_values, x_values), 4)
unique_values = np.unique(array)
len(unique_values)
# Out:
# C:\Users\becneljj\AppData\Local\Temp\ipykernel_31520\53532934.py:6: RuntimeWarning: divide by zero encountered in divide
#   array = np.round(np.divide(y_values, x_values), 4)
# 1001

# %%
unique_values
# Out:
# array([-5.02000000e+02, -2.51500000e+02, -1.68000000e+02, -1.26250000e+02,
#        -1.01200000e+02, -8.45000000e+01, -7.25714000e+01, -6.36250000e+01,
#        -5.66667000e+01, -5.11000000e+01, -4.65455000e+01, -4.27500000e+01,
#        -3.95385000e+01, -3.67857000e+01, -3.44000000e+01, -3.23125000e+01,
#        -3.04706000e+01, -2.88333000e+01, -2.73684000e+01, -2.60500000e+01,
#        -2.48571000e+01, -2.37727000e+01, -2.27826000e+01, -2.18750000e+01,
#        -2.10400000e+01, -2.02692000e+01, -1.95556000e+01, -1.88929000e+01,
#        -1.82759000e+01, -1.77000000e+01, -1.71613000e+01, -1.66563000e+01,
#        -1.61818000e+01, -1.57353000e+01, -1.53143000e+01, -1.49167000e+01,
#        -1.45405000e+01, -1.41842000e+01, -1.38462000e+01, -1.35250000e+01,
#        -1.32195000e+01, -1.29286000e+01, -1.26512000e+01, -1.23864000e+01,
#        -1.21333000e+01, -1.18913000e+01, -1.16596000e+01, -1.14375000e+01,
# ...
